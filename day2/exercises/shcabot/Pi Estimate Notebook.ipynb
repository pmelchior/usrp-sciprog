# %% [markdown]
# Import module and enable plotting

# %%
# %matplotlib inline
import pi_estimate.pi_calc as p

# %% [markdown]
# Estimate values for pi using 100, 1000 and 1e6 'darts'

# %%
pi_100 = p.PiGen(100)
pi_1000 = p.PiGen(1000)
pi_1e6 = p.PiGen(1000000)

# %%
pi_100.pi
# Out:
# 3.36

# %%
pi_1000.pi
# Out:
# 3.172

# %%
pi_1e6.pi
# Out:
# 3.139288

# %% [markdown]
# Run pi estimation for different sample sizes (see argument for MultiPiGen)

# %%
pi_estimates = p.MultiPiGen([10, 50, 100, 500, 1000, 5000, 10000, 50000, 
                         100000, 500000, 1000000])

# %% [markdown]
# Below are the corresponding run times, and their plot against sample size

# %%
pi_estimates.time_list
# Out:
# [2.4080276489257812e-05,
#  7.486343383789062e-05,
#  0.00013494491577148438,
#  0.0010609626770019531,
#  0.0018420219421386719,
#  0.00778508186340332,
#  0.012928962707519531,
#  0.05210590362548828,
#  0.11919903755187988,
#  0.7986660003662109,
#  2.0945630073547363]

# %%
pi_estimates.plot_times()

# %% [markdown]
# Below is a plot of the 'darts' used in the above 1000 point estimate

# %%
pi_1000.plot_points()

# %% [markdown]
# Now we look at statistics for a 100 point estimate run 5000 times (i.e. the histogram, mean, and standard deviation)

# %%
pi_stats = p.ManyPiGen(100, 5000)

# %%
pi_stats.plot_histogram()

# %%
pi_stats.mean
# Out:
# 3.141536000000037

# %%
pi_stats.stdev
# Out:
# 0.0008702504577424326

# %% [markdown]
# Below is a plot of pi estimates for various sample sizes (the horizontal line corresponds to math.pi)

# %%
pi_precision = p.MultiPiGen([100, 200, 300, 400, 500, 600, 700, 800, 900, 
                           1000, 2000, 3000, 4000, 5000, 6000, 7000, 
                           8000, 9000, 10000])

# %%
pi_precision.plot_estimates()
